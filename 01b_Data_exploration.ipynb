# %%
import numpy as np
from utils import utils_gn
import importlib
importlib.reload(utils_gn)
# Out:
# <module 'utils.utils_gn' from '/home/s2228293/Documents/MACMIGS-Year1/Semester2/Extended_Project/MAC-MIGS-extended-project/utils/utils_gn.py'>

# %%
# read the data
data_dict = utils_gn.read_data('data_100cycles.pkl')

# %%
# visualize selected summary data for selected cells
selected_cells = ['b1c1', 'b1c6',
                  'b2c1', 'b2c6',
                  'b3c1', 'b3c6']
selected_features = ['QDischarge', 'chargetime', 'IR', 'Tavg']

utils_gn.summary_data_exploration(data_dict=data_dict, sample_cells=selected_cells, features=selected_features, fname='summary_exploration')

# %%
# visualize in cycle data 
utils_gn.in_cycle_data_exploration(data_dict=data_dict, sample_cycle='100', fname='incycle_exploration')

# %%
# visualize individual features in the summary data other than cycle and QCharge
utils_gn.individual_summary_data_exploration(data_dict=data_dict, fname='individual_summary_exploration')

# %%
# plot the bar chart of the number cells in each batch and also the histogram of eol of cells
utils_gn.plot_eol_cell_frequency()

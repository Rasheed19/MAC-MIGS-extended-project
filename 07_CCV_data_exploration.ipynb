# %%
import matplotlib.pyplot as plt
import numpy as np
from utils import utils_gn, utils_noah, utils_ivc
import importlib
importlib.reload(utils_gn)
importlib.reload(utils_noah)
importlib.reload(utils_ivc)
# Out:
# <module 'utils.utils_ivc' from '/home/s2228293/Documents/MACMIGS-Year1/Semester2/Extended_Project/MAC-MIGS-extended-project/utils/utils_ivc.py'>

# %%
# Load the data
capacity_CCV_df = utils_gn.read_data('capacity_CCV_df.pkl')
capacity_CCV_dict = utils_gn.read_data('capacity_CCV_dict')
CCV_df = utils_gn.read_data('CCV_df.pkl')
CCV_dict = utils_gn.read_data('CCV_dict.pkl')

# %%
# Plot features as a function of cycles for all cells in each batch
utils_ivc.plot_CCV_features(capacity_CCV_dict, ylabel='cycle', option=1)

# %%
# Plot CCV as a function of time for each cycle for selected cells
utils_ivc.plot_CCV_features(CCV_dict, sample_cells=['b1c30', 'b2c1', 'b3c10'], option=2)
